# %% [markdown]
# # Closed Form Equations
#
# - `variables` are the symbolic variables
# - `equations` are the circuit, power, and control relationships between variables
# - `solutions` are the currents and voltages for each regime

# %%
import ev_model as evc

# %%
variables = evc.define_variables()

# %%
variables
# Out:
# (I_b, I_c, V_b, V_c, Rₘ, k, ω, R_b, V_oc, Iₘₘ, I_bm, τ)

# %%
equations = evc.define_equations_3p(*variables)

# %%
equations
# Out:
# ⎛          3⋅I_c⋅V_c                 √3⋅k⋅ω
# ⎜I_b⋅V_b = ─────────, V_c = I_c⋅Rₘ + ──────, V_oc = I_b⋅R_b + V_b, I_c = Iₘₘ,
# ⎝              2                       3
#
#             √3⋅V_b      ⎞
# I_b = I_bm, ────── = V_c⎟
#               3         ⎠

# %%
solutions = evc.solve_equations(*equations, *variables)

# %%
solutions
# Out:
# ⎛⎧               ____________________________________________
# ⎜⎪              ╱        2                                 2
# ⎜⎨     V_oc - ╲╱  - 6⋅Iₘₘ ⋅R_b⋅Rₘ - 2⋅√3⋅Iₘₘ⋅R_b⋅k⋅ω + V_oc
# ⎜⎪I_b: ──────────────────────────────────────────────────────, I_c: Iₘₘ, V_b:
# ⎝⎩                             2⋅R_b
#
#           ____________________________________________                      ⎫
#          ╱        2                                 2                       ⎪
# V_oc   ╲╱  - 6⋅Iₘₘ ⋅R_b⋅Rₘ - 2⋅√3⋅Iₘₘ⋅R_b⋅k⋅ω + V_oc                  √3⋅k⋅ω⎬
# ──── + ───────────────────────────────────────────────, V_c: Iₘₘ⋅Rₘ + ──────⎪,
#  2                            2                                         3   ⎭
#
#  ⎧                   ⎛          ___________________________________________⎞
#  ⎪                   ⎜         ╱         2                            2  2 ⎟
#  ⎨                √3⋅⎝-k⋅ω + ╲╱  - 8⋅I_bm ⋅R_b⋅Rₘ + 8⋅I_bm⋅Rₘ⋅V_oc + k ⋅ω  ⎠
# ...
